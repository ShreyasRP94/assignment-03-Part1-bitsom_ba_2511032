# %%
# Raw Data provided in the problem statement

raw_students = [
    {"name": "  ayesha SHARMA  ", "roll": "101", "marks_str": "88, 72, 95, 60, 78"},
    {"name": "ROHIT verma",       "roll": "102", "marks_str": "55, 68, 49, 72, 61"},
    {"name": "  Priya Nair  ",    "roll": "103", "marks_str": "91, 85, 88, 94, 79"},
    {"name": "karan MEHTA",       "roll": "104", "marks_str": "40, 55, 38, 62, 50"},
    {"name": " Sneha pillai ",    "roll": "105", "marks_str": "75, 80, 70, 68, 85"},
]

print(raw_students)
# Out:
# [{'name': '  ayesha SHARMA  ', 'roll': '101', 'marks_str': '88, 72, 95, 60, 78'}, {'name': 'ROHIT verma', 'roll': '102', 'marks_str': '55, 68, 49, 72, 61'}, {'name': '  Priya Nair  ', 'roll': '103', 'marks_str': '91, 85, 88, 94, 79'}, {'name': 'karan MEHTA', 'roll': '104', 'marks_str': '40, 55, 38, 62, 50'}, {'name': ' Sneha pillai ', 'roll': '105', 'marks_str': '75, 80, 70, 68, 85'}]

# %%
# Name cleaning separately

for s in raw_students:
    original = s["name"]
    cleaned = original.strip().title()
    print(f"Original: '{original}' -> Cleaned: '{cleaned}'")
# Out:
# Original: '  ayesha SHARMA  ' -> Cleaned: 'Ayesha Sharma'
# Original: 'ROHIT verma' -> Cleaned: 'Rohit Verma'
# Original: '  Priya Nair  ' -> Cleaned: 'Priya Nair'
# Original: 'karan MEHTA' -> Cleaned: 'Karan Mehta'
# Original: ' Sneha pillai ' -> Cleaned: 'Sneha Pillai'

# %%
# Marks conversion

for s in raw_students:
    raw_marks = s["marks_str"]
    split_marks = raw_marks.split(",")
    
    marks = []
    for m in split_marks:
        marks.append(int(m))
    
    print(raw_marks, "->", marks)
# Out:
# 88, 72, 95, 60, 78 -> [88, 72, 95, 60, 78]
# 55, 68, 49, 72, 61 -> [55, 68, 49, 72, 61]
# 91, 85, 88, 94, 79 -> [91, 85, 88, 94, 79]
# 40, 55, 38, 62, 50 -> [40, 55, 38, 62, 50]
# 75, 80, 70, 68, 85 -> [75, 80, 70, 68, 85]

# %%
# Building cleaned students dataset

students_clean = []

for s in raw_students:
    
    # Name
    name_clean = s["name"].strip().title()
    
    # Roll
    roll_num = int(s["roll"])
    
    # Marks
    marks_temp = s["marks_str"].split(",")
    marks = []
    for m in marks_temp:
        marks.append(int(m))
    
    student_obj = {
        "name": name_clean,
        "roll": roll_num,
        "marks": marks
    }
    
    students_clean.append(student_obj)

students_clean
# Out:
# [{'name': 'Ayesha Sharma', 'roll': 101, 'marks': [88, 72, 95, 60, 78]},
#  {'name': 'Rohit Verma', 'roll': 102, 'marks': [55, 68, 49, 72, 61]},
#  {'name': 'Priya Nair', 'roll': 103, 'marks': [91, 85, 88, 94, 79]},
#  {'name': 'Karan Mehta', 'roll': 104, 'marks': [40, 55, 38, 62, 50]},
#  {'name': 'Sneha Pillai', 'roll': 105, 'marks': [75, 80, 70, 68, 85]}]

# %%
# Name validity test

for s in students_clean:
    name = s["name"]
    
    valid = True
    words = name.split()
    
    for w in words:
        if not w.isalpha():
            valid = False
    
    if valid:
        print(name, "- ✓ Valid name")
    else:
        print(name, "- ✗ Invalid name")
# Out:
# Ayesha Sharma - ✓ Valid name
# Rohit Verma - ✓ Valid name
# Priya Nair - ✓ Valid name
# Karan Mehta - ✓ Valid name
# Sneha Pillai - ✓ Valid name

# %%
# Profile card display

for s in students_clean:
    
    print("=" * 32)
    print(f"Student : {s['name']}")
    print(f"Roll No : {s['roll']}")
    print(f"Marks   : {s['marks']}")
    print("=" * 32)
# Out:
# ...
# Student : Ayesha Sharma
# Roll No : 101
# Marks   : [88, 72, 95, 60, 78]
# ...
# Student : Rohit Verma
# Roll No : 102
# Marks   : [55, 68, 49, 72, 61]
# ...
# Student : Priya Nair
# Roll No : 103
# Marks   : [91, 85, 88, 94, 79]
# ...
# Student : Karan Mehta
# Roll No : 104
# Marks   : [40, 55, 38, 62, 50]
# ...
# Student : Sneha Pillai
# Roll No : 105
# Marks   : [75, 80, 70, 68, 85]
# ...

# %%
# Print the name in ALL CAPS and lowercase for the student with roll number 103

for s in students_clean:
    if s["roll"] == 103:
        name = s["name"]
        print("Uppercase :", name.upper())
        print("Lowercase :", name.lower())
# Out:
# Uppercase : PRIYA NAIR
# Lowercase : priya nair

# %% [markdown]
# **# Task2 **
